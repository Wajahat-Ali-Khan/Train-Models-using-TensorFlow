# %%
import tensorflow as tf
print(tf.__version__)
from tensorflow.keras import optimizers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from tensorflow.keras.utils import to_categorical
# Out:
# 2.0.0

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 34s 3us/step

# %%
from tensorflow.keras import models
from tensorflow.keras import layers
data = models.Sequential()
data.add(layers.Dense(512, activation="relu", input_shape=(28*28,)))
data.add(layers.Dense(10, activation="softmax" ))

# %%
#NORMALIZE THE DATA IN SEQUENCE, CLOSEST TO EACH OTHER
train_images = train_images.reshape((60000,28*28))#CONVERT IN 2 DIMENSIONS
train_images = train_images.astype('float32')/255
test_images = test_images.reshape((10000,28*28))
test_images = test_images.astype('float32')/255

# %%
data.compile(optimizer="rmsprop",
              metrics = ['accuracy'],
              loss = 'binary_crossentropy'
)

# %%
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
data.fit(train_images, train_labels, epochs=10, batch_size=128)
# Out:
# Train on 60000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 8s 132us/sample - loss: 0.0441 - accuracy: 0.9851
# Epoch 2/10
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.0191 - accuracy: 0.9938
# Epoch 3/10
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.0128 - accuracy: 0.9959
# Epoch 4/10
# 60000/60000 [==============================] - 5s 77us/sample - loss: 0.0095 - accuracy: 0.9970
# Epoch 5/10
# 60000/60000 [==============================] - 4s 71us/sample - loss: 0.0073 - accuracy: 0.9977
# Epoch 6/10
# 60000/60000 [==============================] - 4s 73us/sample - loss: 0.0055 - accuracy: 0.9983
# Epoch 7/10
# 60000/60000 [==============================] - 5s 81us/sample - loss: 0.0043 - accuracy: 0.9986
# Epoch 8/10
# 60000/60000 [==============================] - 6s 92us/sample - loss: 0.0034 - accuracy: 0.9990
# Epoch 9/10
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.0026 - accuracy: 0.9992
# Epoch 10/10
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.0021 - accuracy: 0.9994

# %%
test_loss, test_acc = data.evaluate(test_images, test_labels)
print("test accuracy = ",test_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# test accuracy =  0.99626964
